# %%
# !pip install TTS

# %%
import torch
from TTS.api import TTS

# Get device
device = "cuda" if torch.cuda.is_available() else "cpu"

# List available 🐸TTS models
print(TTS().list_models())

# Init TTS
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2").to(device)

# Run TTS
# ❗ Since this model is multi-lingual voice cloning model, we must set the target speaker_wav and language
# Text to speech list of amplitude values as output
wav = tts.tts(text="Hello world!", speaker_wav="/content/Carnegie-Mellon-University.wav", language="en")
# Text to speech to a file
tts.tts_to_file(text="Hello world!", speaker_wav="/content/Carnegie-Mellon-University.wav", language="en", file_path="output.wav")
# Out:
# ...
#  > tts_models/multilingual/multi-dataset/xtts_v2 is already downloaded.
#  > Using model: xtts
#  > Text splitted to sentences.
# ['Hello world!']
#  > Processing time: 5.787117958068848
#  > Real-time factor: 2.25484080745367
#  > Text splitted to sentences.
# ['Hello world!']
#  > Processing time: 1.28745436668396
#  > Real-time factor: 0.49053719908386295
# 'output.wav'

# %%
speaker_wav = "/content/trump_ref.wav"
text = "Ich liebe Carnegie Mellon Universität, aber ich bin nicht intelligent genug, um zur Schule gehen"

tts.tts_to_file(text=text, speaker_wav=speaker_wav, language="en", file_path="output.wav")
# Out:
#  > Text splitted to sentences.
# ['Ich liebe Carnegie Mellon Universität, aber ich bin nicht intelligent genug, um zur Schule gehen']
#  > Processing time: 4.525501728057861
#  > Real-time factor: 0.5861015946790471
# 'output.wav'

# %%
from IPython.display import Audio

# Play the audio file
Audio("/content/output.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
